# %% [markdown]
# # QUESTION 5

# %% [markdown]
# You can use any standard libraries of your choice. You can use any programming language or framework.
#
# Please choose five different datasets that have sufficiently different characteristics. Then choose five different clustering algorithms.
#
# Then write/import some code to produce a grid of 5 datasets x 5 clustering algorithms results. Then vary some parameters of the clustering algorithms to demonstrate which algorithms work best on which datasets.
#
# Finally, comment on the performance, the reasons for the same and then extend the system to a clustering algorithm of your own. This new clustering algorithm can be entirely new or a hybrid of the clustering algorithms you chose initially, but must work better than all other clustering algorithms on three of the initially chosen datasets. Add this as a final clustering column in your results grid to show the 5 dataset rows x 6 clustering algorithms results table.

# %% [markdown]
# # References

# %% [markdown]
# https://matplotlib.org/
# for plotting of the datapoints after using an algorithm
#
# **Pros**
#
# *   Number of examples of different kinds of plots using matplotlib
#
# **Cons**
#
# * Few scatter plot examples
# * Basic explaination in subplots

# %% [markdown]
# https://machinelearningmastery.com/clustering-algorithms-with-python/
#  for clustering algorithms
#
# **Pros**
#
# *   Clear explain of the algorithms and how the perform
# *   Examples with codes given
#
# **Cons**
#
# * No demonstration of the differences in performance for the clustering algorithm

# %% [markdown]
# # Clustering Algorithms to be used

# %% [markdown]
# Clustering is an unsupervised problem of finding natural groups in the feature space of input data.

# %% [markdown]
# 1.   **Affinity Propagation** : Involves finding a set of exemplars that best summarize the data.
# 2.   **K-Means** : Involves assigning examples to clusters in an effort to minimize the variance within each cluster
# 3.   **DBSCAN** : (where DBSCAN is short for Density-Based Spatial Clustering of Applications with Noise) involves finding high-density areas in the domain and expanding those areas of the feature space around them as clusters.
# 4.   **Spectral** : A general class of clustering methods, drawn from linear algebra.
# 5.   **Gaussian Mixture Model (GMM)** : Summarizes a multivariate probability density function with a mixture of Gaussian probability distributions as its name suggests.

# %% [markdown]
# # Importing necessary Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
import pandas as pd

# load sklearn libraries
from sklearn import datasets
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import DBSCAN, SpectralClustering
from sklearn.datasets import make_moons
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AffinityPropagation
from matplotlib import pyplot
# k-means clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
from matplotlib import pyplot

print(__doc__)

import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)
import sklearn
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# # Defining helper functions for creating datasets and plots

# %%
def load_microbial_data(n=500):
    z = np.random.randint(0, high=3, size=(n,))
    c1 = np.random.multivariate_normal([-1.0, -1.0], [[0.3, 0.1], [0.1, 0.3]], size=n)
    c2 = np.random.multivariate_normal([1.5, -1.5], [[2.8, -0.2], [-0.2, 3.2]], size=n)
    c3 = np.random.multivariate_normal([0.0, 1.0], [[1., 0.0], [0.0, 0.2]], size=n)

    samples = 0.0
    for idx, c in enumerate([c1, c2, c3]):
        samples += c * np.expand_dims(z == idx, axis=-1)

    return samples


def load_moons_data(n=500):
    return make_moons(n_samples=n, noise=0.17)[0]

def load_cicles(n=500):
  return sklearn.datasets.make_circles(n_samples=n, factor=.5,
                                      noise=.05)[0]
def load_noStructure(n=500):
  return datasets.make_blobs(n_samples=500,
                             cluster_std=[1.0, 2.5, 0.5],)[0]

def load_bloobs(n=500):
  return sklearn.datasets.make_blobs(n_samples=n, random_state=8)[0]

def plot_first_two_features(X):
    plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()

def plot_clusters(X, z_predict, centers=None):
    plt.scatter(X[:, 0], X[:, 1], c=z_predict, s=50, cmap='viridis', alpha=0.5)
    if centers is not None:
        plt.scatter(centers[:, 0], centers[:, 1], c='black', edgecolors='white', s=100)
    plt.show()

# %% [markdown]
# # Loading the five datasets

# %%
#loading data set

x1=load_microbial_data()
x2=load_moons_data()
x3=load_cicles()
x4=load_noStructure()
x5=load_bloobs()

# %% [markdown]
# # Viewing the datasets

# %%
plot_first_two_features(x1)

# %%
plot_first_two_features(x2)

# %%
plot_first_two_features(x3)

# %%
plot_first_two_features(x4)

# %%
plot_first_two_features(x5)

# %%
dataset=[x1,x2,x3,x4,x5]

for i in dataset:
  plot_first_two_features(i)

# %% [markdown]
# # Clustering Algorithms

# %%
#aLGORITHMS
ap = AffinityPropagation(damping=0.9)
kmeans=KMeans(n_clusters=2)
dbscan=DBSCAN()
spectral=SpectralClustering()
gmm=GaussianMixture()
algorithms=[ap,kmeans,dbscan,spectral,gmm]

# %%
ypred=ap.predict(x1)
ypred=ap.predict(x)
ypred=ap.predict(x1)
ypred=ap.predict(x1)
ypred=ap.predict(x1)

# %% [markdown]
# # Parameters

# %%
default_base = {'quantile': .3,
                'eps': .3,
                'damping': .9,
                'preference': -200,
                'n_neighbors': 10,
                'n_clusters': 3,
                'min_samples': 20,
                'xi': 0.05,
                'min_cluster_size': 0.1}

# %% [markdown]
# # Using Dataset 1

# %%
#AFFINITY PROPAGATION
# define the model
model1 = AffinityPropagation(damping=0.9)
# fit the model
model1.fit(x1)
# assign a cluster to each example
yhat = model1.predict(x1)
# Step 3: Visualize the clusters
plot_clusters(x1, yhat)


#K-MEANS
# define the model
model = KMeans(n_clusters=2)
# fit the model
model.fit(x1)
# assign a cluster to each example
yhat = model.predict(x1)
plot_clusters(x1, yhat)

#DBSCAN
# Step 1: Instantiate the DBSCAN object
dbscan = DBSCAN(eps=0.4, min_samples=20)

# Step 2: Fit the DBSCAN and get the predictions
clusters = dbscan.fit_predict(x1)

# Step 3: Visualize the clusters
plot_clusters(x1, clusters)

#SPECTRAL
# Step 1: Create the Gaussian Mixture Model objective
spectral = SpectralClustering(n_clusters=3)

# Step 2: Fit the model and use it to predict the clusters
spectral_assignments = spectral.fit_predict(x1)

# Step 3: Visualize the clusters
plot_clusters(x1, spectral_assignments)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=3)

# Step 2: Fit the model
gmm.fit(x1)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x1)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x1, gmm_assignments, centers=centers)

# %% [markdown]
# # Using Dataset 2

# %%
#AFFINITY PROPAGATION
# define the model
model1 = AffinityPropagation(damping=0.9)
# fit the model
model1.fit(x2)
# assign a cluster to each example
yhat = model1.predict(x2)
# Step 3: Visualize the clusters
plot_clusters(x2, yhat)


#K-MEANS
# define the model
model = KMeans(n_clusters=2)
# fit the model
model.fit(x2)
# assign a cluster to each example
yhat = model.predict(x2)
plot_clusters(x2, yhat)

#DBSCAN
# Step 1: Instantiate the DBSCAN object
dbscan = DBSCAN(eps=0.4, min_samples=20)

# Step 2: Fit the DBSCAN and get the predictions
clusters = dbscan.fit_predict(x2)

# Step 3: Visualize the clusters
plot_clusters(x2, clusters)

#SPECTRAL
# Step 1: Create the Gaussian Mixture Model objective
spectral = SpectralClustering(n_clusters=3)

# Step 2: Fit the model and use it to predict the clusters
spectral_assignments = spectral.fit_predict(x2)

# Step 3: Visualize the clusters
plot_clusters(x2, spectral_assignments)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=3)

# Step 2: Fit the model
gmm.fit(x2)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x2)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x2, gmm_assignments, centers=centers)

# %% [markdown]
# # Using Dataset 3

# %%
#AFFINITY PROPAGATION
# define the model
model1 = AffinityPropagation(damping=0.9)
# fit the model
model1.fit(x3)
# assign a cluster to each example
yhat = model1.predict(x3)
# Step 3: Visualize the clusters
plot_clusters(x3, yhat)


#K-MEANS
# define the model
model = KMeans(n_clusters=2)
# fit the model
model.fit(x3)
# assign a cluster to each example
yhat = model.predict(x3)
plot_clusters(x3, yhat)

#DBSCAN
# Step 1: Instantiate the DBSCAN object
dbscan = DBSCAN(eps=0.4, min_samples=20)

# Step 2: Fit the DBSCAN and get the predictions
clusters = dbscan.fit_predict(x3)

# Step 3: Visualize the clusters
plot_clusters(x3, clusters)

#SPECTRAL
# Step 1: Create the Gaussian Mixture Model objective
spectral = SpectralClustering(n_clusters=3)

# Step 2: Fit the model and use it to predict the clusters
spectral_assignments = spectral.fit_predict(x3)

# Step 3: Visualize the clusters
plot_clusters(x3, spectral_assignments)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=3)

# Step 2: Fit the model
gmm.fit(x3)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x3)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x3, gmm_assignments, centers=centers)

# %% [markdown]
# # Using Dataset 4

# %%
#AFFINITY PROPAGATION
# define the model
model1 = AffinityPropagation(damping=0.9)
# fit the model
model1.fit(x4)
# assign a cluster to each example
yhat = model1.predict(x4)
# Step 3: Visualize the clusters
plot_clusters(x4, yhat)


#K-MEANS
# define the model
model = KMeans(n_clusters=2)
# fit the model
model.fit(x4)
# assign a cluster to each example
yhat = model.predict(x4)
plot_clusters(x4, yhat)

#DBSCAN
# Step 1: Instantiate the DBSCAN object
dbscan = DBSCAN(eps=0.4, min_samples=20)

# Step 2: Fit the DBSCAN and get the predictions
clusters = dbscan.fit_predict(x4)

# Step 3: Visualize the clusters
plot_clusters(x4, clusters)

#SPECTRAL
# Step 1: Create the Gaussian Mixture Model objective
spectral = SpectralClustering(n_clusters=3)

# Step 2: Fit the model and use it to predict the clusters
spectral_assignments = spectral.fit_predict(x4)

# Step 3: Visualize the clusters
plot_clusters(x4, spectral_assignments)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=3)

# Step 2: Fit the model
gmm.fit(x4)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x4)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x4, gmm_assignments, centers=centers)

# %% [markdown]
# # Using Dataset 5

# %%
#AFFINITY PROPAGATION
# define the model
model1 = AffinityPropagation(damping=0.9)
# fit the model
model1.fit(x5)
# assign a cluster to each example
yhat = model1.predict(x5)
# Step 3: Visualize the clusters
plot_clusters(x5, yhat)


#K-MEANS
# define the model
model = KMeans(n_clusters=2)
# fit the model
model.fit(x5)
# assign a cluster to each example
yhat = model.predict(x5)
plot_clusters(x5, yhat)

#DBSCAN
# Step 1: Instantiate the DBSCAN object
dbscan = DBSCAN(eps=0.4, min_samples=20)

# Step 2: Fit the DBSCAN and get the predictions
clusters = dbscan.fit_predict(x5)

# Step 3: Visualize the clusters
plot_clusters(x5, clusters)

#SPECTRAL
# Step 1: Create the Gaussian Mixture Model objective
spectral = SpectralClustering(n_clusters=3)

# Step 2: Fit the model and use it to predict the clusters
spectral_assignments = spectral.fit_predict(x5)

# Step 3: Visualize the clusters
plot_clusters(x5, spectral_assignments)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=3)

# Step 2: Fit the model
gmm.fit(x5)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x5)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x5, gmm_assignments, centers=centers)

# %% [markdown]
# # Function to creat a 5x5 grid of datasets by the clustering algorithms

# %% [markdown]
# # Better performing model

# %% [markdown]
# Didnot manage to implement or write a code to produce a grid of 5 datasets x 5 clustering algorithms results. It required defining a function that would iterate in the dataset and aswell that 5 Algorithms.
#
# It is not easy to conclude which clustering algorithm perfomed better infact there no good or bad algorithm. Some are algortithms that have performed well in one dataset didnot perform well in other datasets.
#
# Nevertheless, Spectral and GMM has performed in all the datasets and managed to capture the distribution of the datapoints. The clusters created are not doubtful compared to Affinity Propagation, K-Means and DBSCAN.
#
# I went ahead and fine tuned the GMM to come up with the sixth hybrid algorithm.

# %%
#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=6)

# Step 2: Fit the model
gmm.fit(x1)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x1)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x1, gmm_assignments, centers=centers)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=6)

# Step 2: Fit the model
gmm.fit(x2)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x2)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x2, gmm_assignments, centers=centers)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=6)

# Step 2: Fit the model
gmm.fit(x3)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x3)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x3, gmm_assignments, centers=centers)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=6)

# Step 2: Fit the model
gmm.fit(x4)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x4)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x4, gmm_assignments, centers=centers)

#GMM
# Step 1: Create the Gaussian Mixture Model objective
gmm = GaussianMixture(n_components=6)

# Step 2: Fit the model
gmm.fit(x5)

# Step 3: Predict the clusters
gmm_assignments = gmm.predict(x5)

# Step 4: Get the centers of the clusters
centers = gmm.means_

# Step 5: Visualize the clusters
plot_clusters(x5, gmm_assignments, centers=centers)
